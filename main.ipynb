# %%
from keras.engine.saving import model_from_json
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from keras_preprocessing.image import ImageDataGenerator


class CNN:

    USE_EXISTING_MODEL = False

    def __init__(self):
        model = self.get_model(self.USE_EXISTING_MODEL)
        self.predict_data(model)

    def get_model(self, use_existing_model):
        print("Getting model..")
        if use_existing_model:
            return self.load_model()

        train_data, validation_data = self.load_data()
        model = self.build_model(train_data, validation_data)

        print("Getting model is Finished..")
        return model

    @staticmethod
    def load_model():
        print("Loading model..")
        json_file = open("model/model_structure.json", "r")
        loaded_model_json = json_file.read()
        json_file.close()

        loaded_model = model_from_json(loaded_model_json)
        loaded_model.load_weights("model/model_weight.h5")
        loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
        print("Loading model is Finished..")

        return loaded_model

    @staticmethod
    def save_model(model):
        with open("model/model_structure.json", "w") as json_file:
            print("Saving / Replacing model..")
            model_json = model.to_json()
            json_file.write(model_json)

            model.save_weights("model/model_weight.h5")
            print("Saving / Replacing model is Finished..")

    @staticmethod
    def load_data():
        print("Loading data..")

        train_generator = ImageDataGenerator(width_shift_range=0.2, rotation_range=10)
        train_data = train_generator.flow_from_directory(
            directory="data/train/",
            batch_size=1,
            class_mode="categorical",
            shuffle=True,
            seed=42,
            color_mode="grayscale",
            target_size=(256, 64)
        )

        validation_generator = ImageDataGenerator()
        validation_data = validation_generator.flow_from_directory(
            directory="data/valid/",
            batch_size=1,
            class_mode="categorical",
            shuffle=True,
            seed=42,
            color_mode="grayscale",
            target_size=(256, 64)
        )

        # For showing data
        # x, y = train_data.next()
        # for i in range(0, 3):
        #     # Image file
        #     image = x[i]
        #
        #     # Label = directory label, sort by name
        #     label = y[i]
        #
        #     pyplot.imshow(numpy.squeeze(image))
        #     pyplot.show()

        print("Loading data is Finished..")
        return train_data, validation_data

    def build_model(self, train_data, validation_data):
        print("Building model..")
        model = Sequential()

        model.add(Conv2D(32, kernel_size=4, activation='relu', input_shape=(256, 64, 1), padding='same'))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(256, 64, 1), padding='same'))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(128, kernel_size=2, activation='relu', input_shape=(256, 64, 1), padding='same'))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(256, kernel_size=2, activation='relu', input_shape=(256, 64, 1), padding='same'))
        model.add(Flatten())
        model.add(Dense(256))
        model.add(Dense(128))
        model.add(Dense(64))
        model.add(Dense(32))
        model.add(Dense(13, activation='softmax'))
        model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

        print(model.summary())

        # TODO: Check Point
        # TODO: Early Stopping
        model.fit_generator(
            generator=train_data,
            validation_data=validation_data,
            epochs=100,
            verbose=1
        )

        self.save_model(model)

        print("Building model is Finished..")
        return model

    @staticmethod
    def predict_data(model):
        test_generator = ImageDataGenerator()
        test_data = test_generator.flow_from_directory(
            directory="data/test/",
            batch_size=1,
            class_mode="categorical",
            shuffle=False,
            color_mode="grayscale",
            target_size=(256, 64)
        )

        loss, accuracy = model.evaluate_generator(
            generator=test_data
        )

        print(
            ""
            "Prediction Loss: %2d\n"
            "Prediction Accuracy: %2d%%"
            ""
            % (loss, accuracy * 100))

    def predict_manual(model):
        result = model.predict_generator(
            generator=test_data
        )

        classes = os.listdir("data/train")
        if ".DS_Store" in classes:
            classes.remove(".DS_Store")
            classes = sorted(classes)
        
        for val in result.argmax(axis=-1):
            print(classes[val])
        
        print([map(int, classes[x]) for x in result.argmax(axis=-1)])


if __name__ == "__main__":
    CNN()
# Out:
# Getting model..
# Loading data..
# Found 975 images belonging to 13 classes.
# Found 325 images belonging to 13 classes.
# Loading data is Finished..
# Building model..
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 256, 64, 32)       544
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 128, 32, 64)       18496
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 64, 16, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 64, 16, 128)       32896
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 32, 8, 128)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 32, 8, 256)        131328
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 65536)             0
# _________________________________________________________________
# dense_57 (Dense)             (None, 256)               16777472
# _________________________________________________________________
# dense_58 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_59 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_60 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_61 (Dense)             (None, 13)                429
# =================================================================
# Total params: 17,004,397
# Trainable params: 17,004,397
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 975/975 [==============================] - 24s 25ms/step - loss: 15.3903 - accuracy: 0.1579 - val_loss: 2.4603 - val_accuracy: 0.2185
# Epoch 2/100
# 975/975 [==============================] - 24s 24ms/step - loss: 2.4542 - accuracy: 0.2174 - val_loss: 2.5979 - val_accuracy: 0.2954
# Epoch 3/100
# 975/975 [==============================] - 24s 24ms/step - loss: 2.5240 - accuracy: 0.2431 - val_loss: 2.6434 - val_accuracy: 0.1662
# Epoch 4/100
# 975/975 [==============================] - 24s 25ms/step - loss: 2.1068 - accuracy: 0.2677 - val_loss: 2.2884 - val_accuracy: 0.3569
# Epoch 5/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.8104 - accuracy: 0.3559 - val_loss: 1.7622 - val_accuracy: 0.3600
# Epoch 6/100
# 975/975 [==============================] - 24s 24ms/step - loss: 1.7237 - accuracy: 0.3826 - val_loss: 1.4461 - val_accuracy: 0.2985
# Epoch 7/100
# 975/975 [==============================] - 24s 24ms/step - loss: 1.6204 - accuracy: 0.3754 - val_loss: 2.1384 - val_accuracy: 0.4185
# Epoch 8/100
# 975/975 [==============================] - 24s 24ms/step - loss: 1.5762 - accuracy: 0.3938 - val_loss: 1.1329 - val_accuracy: 0.4154
# Epoch 9/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.5520 - accuracy: 0.3836 - val_loss: 0.6290 - val_accuracy: 0.3415
# Epoch 10/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.8639 - accuracy: 0.3579 - val_loss: 3.9695 - val_accuracy: 0.3046
# Epoch 11/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.6925 - accuracy: 0.3662 - val_loss: 1.4923 - val_accuracy: 0.3785
# Epoch 12/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.5230 - accuracy: 0.3979 - val_loss: 4.2711 - val_accuracy: 0.3815
# Epoch 13/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.6332 - accuracy: 0.3867 - val_loss: 0.9050 - val_accuracy: 0.4123
# Epoch 14/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.4912 - accuracy: 0.4318 - val_loss: 3.0115 - val_accuracy: 0.4431
# Epoch 15/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.4908 - accuracy: 0.4256 - val_loss: 1.0406 - val_accuracy: 0.4000
# Epoch 16/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1.5272 - accuracy: 0.4154 - val_loss: 5.9127 - val_accuracy: 0.3538
# Epoch 17/100
# 975/975 [==============================] - 24s 25ms/step - loss: 1
100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.4542 - accuracy: 0.8390 - val_loss: 1.1176 - val_accuracy: 0.7569
# Epoch 45/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.6073 - accuracy: 0.8082 - val_loss: 3.3616e-05 - val_accuracy: 0.7877
# Epoch 46/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.5703 - accuracy: 0.8256 - val_loss: 0.0168 - val_accuracy: 0.7908
# Epoch 47/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.4970 - accuracy: 0.8400 - val_loss: 1.0729e-06 - val_accuracy: 0.8215
# Epoch 48/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.5416 - accuracy: 0.8359 - val_loss: 4.3327 - val_accuracy: 0.7877
# Epoch 49/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.5705 - accuracy: 0.8246 - val_loss: 0.9087 - val_accuracy: 0.7385
# Epoch 50/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.5515 - accuracy: 0.8410 - val_loss: 0.0353 - val_accuracy: 0.8246
# Epoch 51/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.4390 - accuracy: 0.8667 - val_loss: 0.0025 - val_accuracy: 0.8215
# Epoch 52/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.4152 - accuracy: 0.8503 - val_loss: 4.1318 - val_accuracy: 0.7477
# Epoch 53/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.4613 - accuracy: 0.8595 - val_loss: 0.2069 - val_accuracy: 0.7385
# Epoch 54/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.5936 - accuracy: 0.8133 - val_loss: 0.0357 - val_accuracy: 0.7785
# Epoch 55/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.4293 - accuracy: 0.8605 - val_loss: 0.3292 - val_accuracy: 0.7785
# Epoch 56/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.4736 - accuracy: 0.8431 - val_loss: 0.0668 - val_accuracy: 0.7815
# Epoch 57/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.3970 - accuracy: 0.8800 - val_loss: 10.5725 - val_accuracy: 0.7508
# Epoch 58/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.4137 - accuracy: 0.8697 - val_loss: 0.0010 - val_accuracy: 0.7815
# Epoch 59/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3751 - accuracy: 0.8718 - val_loss: 1.5007e-04 - val_accuracy: 0.8277
# Epoch 60/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.5402 - accuracy: 0.8359 - val_loss: 0.2033 - val_accuracy: 0.8123
# Epoch 61/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3493 - accuracy: 0.8831 - val_loss: 0.0062 - val_accuracy: 0.8000
# Epoch 62/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.4516 - accuracy: 0.8554 - val_loss: 3.8062 - val_accuracy: 0.7877
# Epoch 63/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.5474 - accuracy: 0.8451 - val_loss: 0.3460 - val_accuracy: 0.7723
# Epoch 64/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.2868 - accuracy: 0.8954 - val_loss: 0.0136 - val_accuracy: 0.7662
# Epoch 65/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.5509 - accuracy: 0.8410 - val_loss: 0.0047 - val_accuracy: 0.7538
# Epoch 66/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3793 - accuracy: 0.8841 - val_loss: 0.0056 - val_accuracy: 0.7846
# Epoch 67/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3873 - accuracy: 0.8769 - val_loss: 0.0076 - val_accuracy: 0.7662
# Epoch 68/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3550 - accuracy: 0.8790 - val_loss: 0.1408 - val_accuracy: 0.8585
# Epoch 69/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3670 - accuracy: 0.8954 - val_loss: 1.0129 - val_accuracy: 0.8062
# Epoch 70/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3664 - accuracy: 0.8749 - val_loss: 1.6231 - val_accuracy: 0.8462
# Epoch 71/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3968 - accuracy: 0.8862 - val_loss: 9.5882e-04 - val_accuracy: 0.8062
# Epoch 72/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.8666 - accuracy: 0.8462 - val_loss: 9.5679e-04 - val_accuracy: 0.7108
# Epoch 73/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.4836 - accuracy: 0.8667 - val_loss: 0.0105 - val_accuracy: 0.8431
# Epoch 74/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3047 - accuracy: 0.8995 - val_loss: 6.4102e-04 - val_accuracy: 0.8585
# Epoch 75/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3795 - accuracy: 0.8913 - val_loss: 0.0012 - val_accuracy: 0.7385
# Epoch 76/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.3478 - accuracy: 0.8944 - val_loss: 3.7514 - val_accuracy: 0.8308
# Epoch 77/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3264 - accuracy: 0.8995 - val_loss: 1.2651 - val_accuracy: 0.6277
# Epoch 78/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.3268 - accuracy: 0.8892 - val_loss: 0.0409 - val_accuracy: 0.5169
# Epoch 79/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.4973 - accuracy: 0.8574 - val_loss: 0.0000e+00 - val_accuracy: 0.7877
# Epoch 80/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.3150 - accuracy: 0.9056 - val_loss: 0.0011 - val_accuracy: 0.7692
# Epoch 81/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.3383 - accuracy: 0.8985 - val_loss: 0.0036 - val_accuracy: 0.8615
# Epoch 82/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.2907 - accuracy: 0.9262 - val_loss: 0.0162 - val_accuracy: 0.8277
# Epoch 83/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.4859 - accuracy: 0.8513 - val_loss: 0.0018 - val_accuracy: 0.7631
# Epoch 84/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3342 - accuracy: 0.8892 - val_loss: 3.9367e-04 - val_accuracy: 0.7846
# Epoch 85/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.4114 - accuracy: 0.8862 - val_loss: 20.8190 - val_accuracy: 0.7969
# Epoch 86/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.6335 - accuracy: 0.8472 - val_loss: 8.1065e-04 - val_accuracy: 0.8338
# Epoch 87/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.2841 - accuracy: 0.9128 - val_loss: 0.0025 - val_accuracy: 0.8615
# Epoch 88/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3331 - accuracy: 0.8974 - val_loss: 1.1921e-07 - val_accuracy: 0.8215
# Epoch 89/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3740 - accuracy: 0.8903 - val_loss: 3.7908e-05 - val_accuracy: 0.7815
# Epoch 90/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3329 - accuracy: 0.9015 - val_loss: 0.0065 - val_accuracy: 0.8185
# Epoch 91/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.2305 - accuracy: 0.9395 - val_loss: 0.0062 - val_accuracy: 0.8031
# Epoch 92/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3405 - accuracy: 0.9036 - val_loss: 45.1273 - val_accuracy: 0.8585
# Epoch 93/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.4426 - accuracy: 0.8790 - val_loss: 5.7550e-04 - val_accuracy: 0.8000
# Epoch 94/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3230 - accuracy: 0.9036 - val_loss: 0.5037 - val_accuracy: 0.6738
# Epoch 95/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3006 - accuracy: 0.9087 - val_loss: 0.6582 - val_accuracy: 0.8400
# Epoch 96/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3001 - accuracy: 0.9005 - val_loss: 5.4928e-04 - val_accuracy: 0.8492
# Epoch 97/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.4043 - accuracy: 0.8882 - val_loss: 0.0083 - val_accuracy: 0.7662
# Epoch 98/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3206 - accuracy: 0.9026 - val_loss: 12.2390 - val_accuracy: 0.8092
# Epoch 99/100
# 975/975 [==============================] - 24s 25ms/step - loss: 0.3487 - accuracy: 0.8882 - val_loss: 0.0800 - val_accuracy: 0.8092
# Epoch 100/100
# 975/975 [==============================] - 24s 24ms/step - loss: 0.3048 - accuracy: 0.9097 - val_loss: 0.2624 - val_accuracy: 0.8585
# Saving / Replacing model..
# Saving / Replacing model is Finished..
# Building model is Finished..
# Getting model is Finished..
# Found 325 images belonging to 13 classes.
# Prediction Loss:  3
# Prediction Accuracy: 80%
