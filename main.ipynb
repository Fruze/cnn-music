# %%
from keras.engine.saving import model_from_json
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from keras_preprocessing.image import ImageDataGenerator


class CNN:

    USE_EXISTING_MODEL = False

    def __init__(self):
        model = self.get_model(self.USE_EXISTING_MODEL)
        self.predict_data(model)

    def get_model(self, use_existing_model):
        print("Getting model..")
        if use_existing_model:
            return self.load_model()

        train_data, validation_data = self.load_data()
        model = self.build_model(train_data, validation_data)

        print("Getting model is Finished..")
        return model

    @staticmethod
    def load_model():
        print("Loading model..")
        json_file = open("model/model_structure.json", "r")
        loaded_model_json = json_file.read()
        json_file.close()

        loaded_model = model_from_json(loaded_model_json)
        loaded_model.load_weights("model/model_weight.h5")
        loaded_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
        print("Loading model is Finished..")

        return loaded_model

    @staticmethod
    def save_model(model):
        with open("model/model_structure.json", "w") as json_file:
            print("Saving / Replacing model..")
            model_json = model.to_json()
            json_file.write(model_json)

            model.save_weights("model/model_weight.h5")
            print("Saving / Replacing model is Finished..")

    @staticmethod
    def load_data():
        print("Loading data..")

        train_generator = ImageDataGenerator(width_shift_range=0.2, rotation_range=10)
        train_data = train_generator.flow_from_directory(
            directory="data/train2/",
            batch_size=1,
            class_mode="categorical",
            shuffle=True,
            seed=42,
            color_mode="grayscale",
            target_size=(256, 64)
        )

        validation_generator = ImageDataGenerator()
        validation_data = validation_generator.flow_from_directory(
            directory="data/valid2/",
            batch_size=1,
            class_mode="categorical",
            shuffle=True,
            seed=42,
            color_mode="grayscale",
            target_size=(256, 64)
        )

        # For showing data
        # x, y = train_data.next()
        # for i in range(0, 3):
        #     # Image file
        #     image = x[i]
        #
        #     # Label = directory label, sort by name
        #     label = y[i]
        #
        #     pyplot.imshow(numpy.squeeze(image))
        #     pyplot.show()

        print("Loading data is Finished..")
        return train_data, validation_data

    def build_model(self, train_data, validation_data):
        print("Building model..")
        model = Sequential()

        # TODO: Pooling & Dropout
        # TODO: Global Average Pooling
        # TODO: Batch Normalization
        model.add(Conv2D(32, kernel_size=4, activation='relu', input_shape=(256, 64, 1), padding='same'))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(256, 64, 1), padding='same'))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(128, kernel_size=2, activation='relu', input_shape=(256, 64, 1), padding='same'))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(256, kernel_size=2, activation='relu', input_shape=(256, 64, 1), padding='same'))
        model.add(Flatten())
        model.add(Dense(256))
        model.add(Dense(128))
        model.add(Dense(64))
        model.add(Dense(32))
        model.add(Dense(13, activation='softmax'))
        model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

        print(model.summary())

        # TODO: Data Augmentation
        # TODO: Early Stopping
        model.fit_generator(
            generator=train_data,
            validation_data=validation_data,
            epochs=100,
            verbose=1
        )

        self.save_model(model)

        print("Building model is Finished..")
        return model

    @staticmethod
    def predict_data(model):
        test_generator = ImageDataGenerator()
        test_data = test_generator.flow_from_directory(
            directory="data/test2/",
            batch_size=1,
            class_mode="categorical",
            shuffle=False,
            color_mode="grayscale",
            target_size=(256, 64)
        )

        loss, accuracy = model.evaluate_generator(
            generator=test_data
        )

        print(
            ""
            "Prediction Loss: %2d\n"
            "Prediction Accuracy: %2d%%"
            ""
            % (loss, accuracy * 100))

    def predict_manual(model):
        result = model.predict_generator(
            generator=test_data
        )

        classes = os.listdir("data/train")
        if ".DS_Store" in classes:
            classes.remove(".DS_Store")
            classes = sorted(classes)
        
        for val in result.argmax(axis=-1):
            print(classes[val])
        
        print([map(int, classes[x]) for x in result.argmax(axis=-1)])


if __name__ == "__main__":
    CNN()
# Out:
# Getting model..
# Loading data..
# Found 585 images belonging to 13 classes.
# Found 195 images belonging to 13 classes.
# Loading data is Finished..
# Building model..
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 256, 64, 32)       544
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 128, 32, 64)       18496
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 64, 16, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 64, 16, 128)       32896
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 32, 8, 128)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 32, 8, 256)        131328
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_47 (Dense)             (None, 256)               16777472
# _________________________________________________________________
# dense_48 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_50 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_51 (Dense)             (None, 13)                429
# =================================================================
# Total params: 17,004,397
# Trainable params: 17,004,397
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 585/585 [==============================] - 15s 25ms/step - loss: 15.0336 - accuracy: 0.1521 - val_loss: 0.2668 - val_accuracy: 0.2564
# Epoch 2/100
# 585/585 [==============================] - 14s 25ms/step - loss: 2.7404 - accuracy: 0.1453 - val_loss: 2.6581 - val_accuracy: 0.1128
# Epoch 3/100
# 585/585 [==============================] - 14s 25ms/step - loss: 2.4652 - accuracy: 0.1556 - val_loss: 2.4454 - val_accuracy: 0.1795
# Epoch 4/100
# 585/585 [==============================] - 14s 25ms/step - loss: 2.6006 - accuracy: 0.1453 - val_loss: 2.5635 - val_accuracy: 0.1949
# Epoch 5/100
# 585/585 [==============================] - 14s 25ms/step - loss: 2.4094 - accuracy: 0.1932 - val_loss: 0.5121 - val_accuracy: 0.2000
# Epoch 6/100
# 585/585 [==============================] - 15s 25ms/step - loss: 2.0323 - accuracy: 0.3060 - val_loss: 2.5812 - val_accuracy: 0.4000
# Epoch 7/100
# 585/585 [==============================] - 15s 25ms/step - loss: 1.6463 - accuracy: 0.4120 - val_loss: 0.9403 - val_accuracy: 0.4513
# Epoch 8/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.5775 - accuracy: 0.4256 - val_loss: 2.2794 - val_accuracy: 0.4410
# Epoch 9/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.4867 - accuracy: 0.4188 - val_loss: 0.3579 - val_accuracy: 0.4154
# Epoch 10/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.3525 - accuracy: 0.4547 - val_loss: 2.0887 - val_accuracy: 0.5385
# Epoch 11/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.4591 - accuracy: 0.4650 - val_loss: 1.4781 - val_accuracy: 0.4000
# Epoch 12/100
# 585/585 [==============================] - 15s 25ms/step - loss: 1.4054 - accuracy: 0.4479 - val_loss: 1.3618 - val_accuracy: 0.5128
# Epoch 13/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.1970 - accuracy: 0.5744 - val_loss: 3.3057 - val_accuracy: 0.5077
# Epoch 14/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.1299 - accuracy: 0.5932 - val_loss: 0.1617 - val_accuracy: 0.5795
# Epoch 15/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.3288 - accuracy: 0.6068 - val_loss: 1.3348 - val_accuracy: 0.3282
# Epoch 16/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.3507 - accuracy: 0.5333 - val_loss: 0.4572 - val_accuracy: 0.6667
# Epoch 17/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1
100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.5635 - accuracy: 0.8513 - val_loss: 2.9013 - val_accuracy: 0.6359
# Epoch 46/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.5359 - accuracy: 0.8359 - val_loss: 5.0663e-05 - val_accuracy: 0.8410
# Epoch 47/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.3887 - accuracy: 0.8855 - val_loss: 0.0372 - val_accuracy: 0.8308
# Epoch 48/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.4209 - accuracy: 0.8615 - val_loss: 3.0756e-05 - val_accuracy: 0.7641
# Epoch 49/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.7541 - accuracy: 0.8154 - val_loss: 0.0460 - val_accuracy: 0.8205
# Epoch 50/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.4985 - accuracy: 0.8752 - val_loss: 1.0609e-04 - val_accuracy: 0.8410
# Epoch 51/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.2100 - accuracy: 0.9214 - val_loss: 0.0164 - val_accuracy: 0.8359
# Epoch 52/100
# 585/585 [==============================] - 15s 25ms/step - loss: 0.2733 - accuracy: 0.9197 - val_loss: 2.0733 - val_accuracy: 0.8256
# Epoch 53/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.0593 - accuracy: 0.6479 - val_loss: 0.0415 - val_accuracy: 0.7385
# Epoch 54/100
# 585/585 [==============================] - 15s 25ms/step - loss: 0.7410 - accuracy: 0.7726 - val_loss: 27.8521 - val_accuracy: 0.6103
# Epoch 55/100
# 585/585 [==============================] - 14s 25ms/step - loss: 1.0283 - accuracy: 0.7026 - val_loss: 4.2776 - val_accuracy: 0.7538
# Epoch 56/100
# 585/585 [==============================] - 15s 25ms/step - loss: 0.5740 - accuracy: 0.8274 - val_loss: 14.4245 - val_accuracy: 0.7795
# Epoch 57/100
# 585/585 [==============================] - 15s 25ms/step - loss: 0.4530 - accuracy: 0.8513 - val_loss: 0.0000e+00 - val_accuracy: 0.8256
# Epoch 58/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.4423 - accuracy: 0.8547 - val_loss: 0.0000e+00 - val_accuracy: 0.8154
# Epoch 59/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.5194 - accuracy: 0.8786 - val_loss: 9.6835 - val_accuracy: 0.7897
# Epoch 60/100
# 585/585 [==============================] - 15s 25ms/step - loss: 0.4036 - accuracy: 0.8821 - val_loss: 1.3448 - val_accuracy: 0.8718
# Epoch 61/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.3200 - accuracy: 0.9060 - val_loss: 0.8521 - val_accuracy: 0.7744
# Epoch 62/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.5402 - accuracy: 0.8564 - val_loss: 5.2452e-06 - val_accuracy: 0.7897
# Epoch 63/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.2036 - accuracy: 0.9265 - val_loss: 3.5763e-07 - val_accuracy: 0.8564
# Epoch 64/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.2679 - accuracy: 0.9282 - val_loss: 0.0000e+00 - val_accuracy: 0.7744
# Epoch 65/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.8677 - accuracy: 0.8274 - val_loss: 4.7684e-07 - val_accuracy: 0.8103
# Epoch 66/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.2525 - accuracy: 0.9265 - val_loss: 0.0000e+00 - val_accuracy: 0.8154
# Epoch 67/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.2364 - accuracy: 0.9231 - val_loss: 4.0792 - val_accuracy: 0.8718
# Epoch 68/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.3066 - accuracy: 0.9231 - val_loss: 0.0472 - val_accuracy: 0.7692
# Epoch 69/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.6723 - accuracy: 0.8017 - val_loss: 0.0000e+00 - val_accuracy: 0.8564
# Epoch 70/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.2530 - accuracy: 0.9385 - val_loss: 0.0126 - val_accuracy: 0.8615
# Epoch 71/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.4291 - accuracy: 0.8940 - val_loss: 2.1098e-04 - val_accuracy: 0.8667
# Epoch 72/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.9481 - accuracy: 0.7692 - val_loss: 2.4359 - val_accuracy: 0.8513
# Epoch 73/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.4834 - accuracy: 0.8581 - val_loss: 0.0000e+00 - val_accuracy: 0.8359
# Epoch 74/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.5360 - accuracy: 0.8667 - val_loss: 5.9605e-07 - val_accuracy: 0.8359
# Epoch 75/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.3326 - accuracy: 0.9060 - val_loss: 1.2314e-04 - val_accuracy: 0.8154
# Epoch 76/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.4496 - accuracy: 0.8718 - val_loss: 0.0000e+00 - val_accuracy: 0.8462
# Epoch 77/100
# 585/585 [==============================] - 15s 25ms/step - loss: 0.6188 - accuracy: 0.8496 - val_loss: 3.9641 - val_accuracy: 0.8769
# Epoch 78/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.2281 - accuracy: 0.9282 - val_loss: 0.0000e+00 - val_accuracy: 0.8051
# Epoch 79/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.3469 - accuracy: 0.8906 - val_loss: 2.3842e-07 - val_accuracy: 0.8667
# Epoch 80/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.3313 - accuracy: 0.9128 - val_loss: 2.4042 - val_accuracy: 0.7795
# Epoch 81/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.2829 - accuracy: 0.9145 - val_loss: 0.1158 - val_accuracy: 0.8051
# Epoch 82/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.9230 - accuracy: 0.7880 - val_loss: 0.1248 - val_accuracy: 0.6769
# Epoch 83/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.4817 - accuracy: 0.8479 - val_loss: 4.7684e-07 - val_accuracy: 0.7590
# Epoch 84/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.2954 - accuracy: 0.9094 - val_loss: 4.0034e-04 - val_accuracy: 0.8205
# Epoch 85/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.1657 - accuracy: 0.9521 - val_loss: 4.5299e-06 - val_accuracy: 0.8513
# Epoch 86/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.2384 - accuracy: 0.9504 - val_loss: 0.0000e+00 - val_accuracy: 0.7692
# Epoch 87/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.3953 - accuracy: 0.8991 - val_loss: 7.6297 - val_accuracy: 0.7795
# Epoch 88/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.4079 - accuracy: 0.8889 - val_loss: 0.0043 - val_accuracy: 0.8615
# Epoch 89/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.3188 - accuracy: 0.9179 - val_loss: 1.0097e-04 - val_accuracy: 0.8513
# Epoch 90/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.1983 - accuracy: 0.9350 - val_loss: 0.0000e+00 - val_accuracy: 0.8154
# Epoch 91/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.1646 - accuracy: 0.9436 - val_loss: 0.0135 - val_accuracy: 0.8308
# Epoch 92/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.4408 - accuracy: 0.8786 - val_loss: 0.0037 - val_accuracy: 0.8051
# Epoch 93/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.1987 - accuracy: 0.9299 - val_loss: 0.0022 - val_accuracy: 0.8000
# Epoch 94/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.3287 - accuracy: 0.9248 - val_loss: 0.0000e+00 - val_accuracy: 0.8564
# Epoch 95/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.2692 - accuracy: 0.9231 - val_loss: 0.0000e+00 - val_accuracy: 0.8256
# Epoch 96/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.1302 - accuracy: 0.9573 - val_loss: 5.9520 - val_accuracy: 0.8718
# Epoch 97/100
# 585/585 [==============================] - 14s 24ms/step - loss: 0.3427 - accuracy: 0.9214 - val_loss: 0.1326 - val_accuracy: 0.7744
# Epoch 98/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.2404 - accuracy: 0.9453 - val_loss: 0.0000e+00 - val_accuracy: 0.8462
# Epoch 99/100
# 585/585 [==============================] - 15s 25ms/step - loss: 0.2506 - accuracy: 0.9333 - val_loss: 0.0000e+00 - val_accuracy: 0.8410
# Epoch 100/100
# 585/585 [==============================] - 14s 25ms/step - loss: 0.1392 - accuracy: 0.9658 - val_loss: 2.2650e-06 - val_accuracy: 0.8462
# Saving / Replacing model..
# Saving / Replacing model is Finished..
# Building model is Finished..
# Getting model is Finished..
# Found 195 images belonging to 13 classes.
# Prediction Loss:  0
# Prediction Accuracy: 86%
