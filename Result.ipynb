# %% [markdown]
# # # Testing 1
#
# - Best Accuracy: 43%
# - Epoch: 10
#
#
# - 13 Class @ 5 subclass @ 15 train data
# - 1000ms sd 4000ms
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 256, 64, 32)       160
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 524288)            0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                16777248
# _________________________________________________________________
# dense_8 (Dense)              (None, 13)                429
# =================================================================
# ```

# %% [markdown]
# # # Testing 2
#
# - Best Accuracy: 48%
# - Epoch: 10
#
#
# - 13 Class @ 5 subclass @ 15 train data
# - 1000ms sd 4000ms
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 256, 64, 32)       544
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 128, 32, 64)       18496
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 64, 16, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 64, 16, 128)       32896
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 131072)            0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               16777344
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_23 (Dense)             (None, 13)                429
# =================================================================
# ```

# %% [markdown]
# # # Testing 3
#
# - Best Accuracy: 44%
# - Epoch: 10
#
#
# - 13 Class @ 5 subclass @ 15 train data
# - 1000ms sd 4000ms
#
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_35 (Conv2D)           (None, 256, 64, 32)       544
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 128, 32, 64)       18496
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 64, 16, 64)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 64, 16, 128)       32896
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 32, 8, 128)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 32, 8, 256)        131328
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 16, 4, 256)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 16, 4, 512)        524800
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 32768)             0
# _________________________________________________________________
# dense_28 (Dense)             (None, 512)               16777728
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_32 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_33 (Dense)             (None, 13)                429
# =================================================================
# ```

# %% [markdown]
# # # Testing 4
#
# - Best Validation Accuracy: 77%
# - Last Validation Accuracy: 73%
# - Prediction Accuracy: 70%
# - Epoch: 100
#
#
# - 13 Class @ 5 subclass @ 15 train data
# - 1000ms sd 4000ms
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_40 (Conv2D)           (None, 256, 64, 32)       544
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 128, 32, 64)       18496
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 64, 16, 64)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 64, 16, 128)       32896
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 32, 8, 128)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 32, 8, 256)        131328
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 16, 4, 256)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 16, 4, 512)        524800
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 32768)             0
# _________________________________________________________________
# dense_34 (Dense)             (None, 512)               16777728
# _________________________________________________________________
# dense_35 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_37 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_38 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_39 (Dense)             (None, 13)                429
# =================================================================
# ```

# %% [markdown]
# # # Testing 5
#
# - Best Validation Accuracy: 86%
# - Last Validation Accuracy: 84%
# - Prediction Accuracy: 86%
# - Epoch: 100
#
#
# - 13 Class @ 5 subclass @ 15 train data
# - 1000ms sd 4000ms
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 256, 64, 32)       544
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 128, 32, 64)       18496
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 64, 16, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 64, 16, 128)       32896
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 32, 8, 128)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 32, 8, 256)        131328
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_47 (Dense)             (None, 256)               16777472
# _________________________________________________________________
# dense_48 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_50 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_51 (Dense)             (None, 13)                429
# =================================================================
# ```

# %% [markdown]
# # # Testing 6
#
# - Best Validation Accuracy: 86%
# - Last Validation Accuracy: 85%
# - Prediction Accuracy: 80%
# - Epoch: 100
#
#
# - Setelah Augmentation
# - 13 Class @ 5 subclass @  15 train data
# - 0250ms sd 4000ms
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 256, 64, 32)       544
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 128, 32, 32)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 128, 32, 64)       18496
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 64, 16, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 64, 16, 128)       32896
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 32, 8, 128)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 32, 8, 256)        131328
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 65536)             0
# _________________________________________________________________
# dense_57 (Dense)             (None, 256)               16777472
# _________________________________________________________________
# dense_58 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_59 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_60 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_61 (Dense)             (None, 13)                429
# =================================================================
# ```
